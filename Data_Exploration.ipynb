# %% [markdown]
# ## **SGen Project**

# %% [markdown]
# ### **Data exploration**

# %%
#importation des données dans un dossier partagé sur le drive 
from google.colab import drive 
drive.mount ('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random as rd # generating random numbers
import datetime # manipulating date formats
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
GSE92742_Broad_LINCS_cell_info=pd.read_csv('gdrive/My Drive/AIforGenomics2021/Project_SGen/data/GSE92742_Broad_LINCS_cell_info.txt, sep='\t'')
breast_data.xlsx

print('Dimension de la base train:', GSE92742_Broad_LINCS_cell_info.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-c1963fa3344b> in <module>()
# ----> 1 GSE92742_Broad_LINCS_cell_info=pd.read_csv('gdrive/My Drive/AIforGenomics2021/Project_SGen/data/GSE92742_Broad_LINCS_cell_info.txt')
#       2
#       3
#       4 print('Dimension de la base train:', GSE92742_Broad_LINCS_cell_info.shape)
#
# ...

# %%
pip install cmapPy
# Out:
# ...
#      |████████████████████████████████| 153kB 5.7MB/s
# ...

# %%
from cmapPy.pandasGEXpress.parse import parse
import pandas as pd
# Get list of landmark genes
gene_info = pd.read_csv('gdrive/My Drive/AIforGenomics2021/Project_SGen/data/GSE92742_Broad_LINCS_gene_info.txt', sep="\t")
landmark_gene_list = gene_info[gene_info['pr_is_lm'] == 1]["pr_gene_id"].astype(str)
# Load the matrix of differential gene expressions as a pandas dataframe
gene_expr_matrix = parse("gdrive/My Drive/AIforGenomics2021/Project_SGen/data/GSE70138_Broad_LINCS_Level5_COMPZ_n118050x12328.gctx", rid=landmark_gene_list).data_df.T

# %%
breast_data = pd.read_excel('gdrive/My Drive/AIforGenomics2021/Project_SGen/data/breast_data.xlsx')
breast_GSK_1059615_data= pd.read_csv('gdrive/My Drive/AIforGenomics2021/Project_SGen/data/breast_GSK_1059615_data.csv')
GSE70138_Broad_LINCS_sig_info = pd.read_csv('gdrive/My Drive/AIforGenomics2021/Project_SGen/data/GSE70138_Broad_LINCS_sig_info.txt', sep="\t")
GSE70138_Broad_LINCS_sig_metrics = pd.read_csv('gdrive/My Drive/AIforGenomics2021/Project_SGen/data/GSE70138_Broad_LINCS_sig_metrics.txt', sep="\t")
MG_132_DMSO = pd.read_csv('gdrive/My Drive/AIforGenomics2021/Project_SGen/data/MG_132_DMSO.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-e4919317c707> in <module>()
# ----> 1 breast_data = pd.read_excel('gdrive/My Drive/AIforGenomics2021/Project_SGen/data/breast_data.xlsx')
#       2 breast_GSK_1059615_data= pd.read_csv('gdrive/My Drive/AIforGenomics2021/Project_SGen/data/breast_GSK_1059615_data.csv')
#       3 GSE70138_Broad_LINCS_sig_info = pd.read_csv('gdrive/My Drive/AIforGenomics2021/Project_SGen/data/GSE70138_Broad_LINCS_sig_info.txt', sep="\t")
#       4 GSE70138_Broad_LINCS_sig_metrics = pd.read_csv('gdrive/My Drive/AIforGenomics2021/Project_SGen/data/GSE70138_Broad_LINCS_sig_metrics.txt', sep="\t")
#       5 MG_132_DMSO = pd.read_csv('gdrive/My Drive/AIforGenomics2021/Project_SGen/data/MG_132_DMSO.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
# ...

# %%
gene_expr_matrix.head()

# %%
landmark_gene_list.head()

# %%
gene_info.head()

# %%
breast_data.head()

# %%
breast_GSK_1059615_data.head()

# %%
GSE70138_Broad_LINCS_sig_info.head()

# %%
GSE92742_Broad_LINCS_cell_info.head()

# %%
MG_132_DMSO.head()
# Out:
#   class cell type                  cid  ...     23038     57048     79716
# 0  DMSO      A375  LJP005_A375_24H:A03  ... -1.076814 -0.240803  0.105998
# 1  DMSO      A375  LJP005_A375_24H:A04  ... -0.904253  0.040530 -0.619656
# 2  DMSO      A375  LJP005_A375_24H:A05  ... -0.939757 -0.093534 -0.260954
# 3  DMSO      A375  LJP005_A375_24H:A06  ... -0.468805  1.793977 -0.642835
# 4  DMSO      A375  LJP005_A375_24H:B03  ... -0.134766 -0.090636 -0.133798
#
# [5 rows x 981 columns]

# %%
nRow, nCol = GSE92742_Broad_LINCS_cell_info.shape
print(f'There are {nRow} rows and {nCol} columns in GSE92742_Broad_LINCS_cell_info dataframe.')


nRow, nCol = gene_info.shape
print(f'There are {nRow} rows and {nCol} columns in gene_info dataframe.')

nRow, nCol = gene_expr_matrix.shape
print(f'There are {nRow} rows and {nCol} columns in gene_expr_matrix dataframe.')

nRow, nCol = breast_data.shape
print(f'There are {nRow} rows and {nCol} columns in breast_data dataframe.')

nRow, nCol = breast_GSK_1059615_data.shape
print(f'There are {nRow} rows and {nCol} columns in breast_GSK_1059615_data dataframe.')

nRow, nCol = GSE70138_Broad_LINCS_sig_info.shape
print(f'There are {nRow} rows and {nCol} columns in GSE70138_Broad_LINCS_sig_info dataframe.')

nRow, nCol = MG_132_DMSO.shape
print(f'There are {nRow} rows and {nCol} columns in MG_132_DMSO dataframe.')
# Out:
# There are 98 rows and 14 columns in GSE92742_Broad_LINCS_cell_info dataframe.
# There are 12328 rows and 5 columns in gene_info dataframe.
# There are 118050 rows and 978 columns in gene_expr_matrix dataframe.
# There are 20300 rows and 11 columns in breast_data dataframe.
# There are 1299 rows and 979 columns in breast_GSK_1059615_data dataframe.
# There are 118050 rows and 8 columns in GSE70138_Broad_LINCS_sig_info dataframe.
# There are 6915 rows and 981 columns in MG_132_DMSO dataframe.

# %%
base = MG_132_DMSO[MG_132_DMSO['class'] == 'DMSO']
base2 = MG_132_DMSO[MG_132_DMSO['class'] == 'MG-132']
base3 = MG_132_DMSO[MG_132_DMSO['cell type'] == 'MCF7']
print(len(base))
print(len(base2))
print(len(base3))
#print(MG_132_DMSO['cell type'].describe())
# Out:
# 4605
# 2310
# 1075

# %% [markdown]
# Data Visualisation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from umap import UMAP

import sklearn.cluster as cluster
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-973e4a67cb17> in <module>()
#       6 from sklearn.decomposition import PCA
#       7 from sklearn.manifold import TSNE
# ----> 8 from umap import UMAP
#       9
#      10 import sklearn.cluster as cluster
#
# ModuleNotFoundError: No module named 'umap'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
GSE70138_Broad_LINCS_sig_info['cell_id'].unique
# Out:
# <bound method Series.unique of 0             A375
# 1             A375
# 2             A375
# 3             A375
# 4             A375
#             ...
# 118045    YAPC.311
# 118046    YAPC.311
# 118047    YAPC.311
# 118048    YAPC.311
# 118049    YAPC.311
# Name: cell_id, Length: 118050, dtype: object>

# %%
GSE70138_Broad_LINCS_sig_info['pert_type'].unique
# Out:
# <bound method Series.unique of 0         ctl_vehicle
# 1         ctl_vehicle
# 2         ctl_vehicle
# 3         ctl_vehicle
# 4              trt_cp
#              ...
# 118045        trt_xpr
# 118046        trt_xpr
# 118047     ctl_vector
# 118048        trt_xpr
# 118049        trt_xpr
# Name: pert_type, Length: 118050, dtype: object>

# %%
GSE92742_Broad_LINCS_cell_info['primary_site'].unique
# Out:
# <bound method Series.unique of 0       skin
# 1       skin
# 2       lung
# 3       lung
# 4       bone
#        ...
# 93      bone
# 94     liver
# 95    muscle
# 96    muscle
# 97    muscle
# Name: primary_site, Length: 98, dtype: object>

# %%
GSE70138_Broad_LINCS_sig_info.head()
# Out:
#                 sig_id  ...                                          distil_id
# 0  LJP005_A375_24H:A03  ...  LJP005_A375_24H_X1_B19:A03|LJP005_A375_24H_X2_...
# 1  LJP005_A375_24H:A04  ...  LJP005_A375_24H_X1_B19:A04|LJP005_A375_24H_X2_...
# 2  LJP005_A375_24H:A05  ...  LJP005_A375_24H_X1_B19:A05|LJP005_A375_24H_X2_...
# 3  LJP005_A375_24H:A06  ...  LJP005_A375_24H_X1_B19:A06|LJP005_A375_24H_X2_...
# 4  LJP005_A375_24H:A07  ...  LJP005_A375_24H_X1_B19:A07|LJP005_A375_24H_X2_...
#
# [5 rows x 8 columns]

# %%
data = gene_expr_matrix
data.head()
# Out:
# rid                         780      7849  ...     57048     79716
# cid                                        ...
# REP.A001_A375_24H:A03  4.264143  0.057249  ...  1.716090 -0.472335
# REP.A001_A375_24H:A04 -0.382211  0.304313  ... -0.505179 -0.618324
# REP.A001_A375_24H:A05 -0.571711 -0.754999  ... -0.428352  1.584976
# REP.A001_A375_24H:A06  0.584376 -0.589973  ...  0.076562 -0.113679
# REP.A001_A375_24H:A07  0.658348 -0.226854  ... -0.092549  0.423315
#
# [5 rows x 978 columns]

# %%
X = data.values
X[0:5]
# Out:
# array([[ 4.2641425 ,  0.0572492 , -2.1393342 , ..., -0.41942072,
#          1.7160902 , -0.47233537],
#        [-0.3822108 ,  0.30431318, -0.9959235 , ...,  1.0480975 ,
#         -0.505179  , -0.6183239 ],
#        [-0.57171094, -0.75499886, -0.71010953, ..., -0.24946684,
#         -0.42835176,  1.5849757 ],
#        [ 0.5843761 , -0.58997315, -0.02639797, ..., -4.35731   ,
#          0.07656179, -0.11367936],
#        [ 0.6583478 , -0.2268537 , -1.143599  , ..., -0.01198876,
#         -0.09254904,  0.42331532]], dtype=float32)

# %%
X_std = StandardScaler().fit_transform(X)

# %%
#Visualize data using Principal Component Analysis.
print("Principal Component Analysis (PCA)")
pca = PCA(n_components = 2).fit_transform(X_std)
pca_df = pd.DataFrame(data=pca, columns=['PC1','PC2']).join(GSE70138_Broad_LINCS_sig_info)
#palette = sns.color_palette("muted", n_colors=5)
#palette =sns.color_palette('bright')
sns.set_style("white")
sns.scatterplot(x='PC1',y='PC2',hue='cell_id',data=pca_df, linewidth=0.2, s=30, alpha=1).set_title('PCA')
# Out:
# Principal Component Analysis (PCA)
# Text(0.5, 1.0, 'PCA')

# %%
#Visualize data using Principal Component Analysis.
print("Principal Component Analysis (PCA)")
pca = PCA(n_components = 2).fit_transform(X_std)
pca_df = pd.DataFrame(data=pca, columns=['PC1','PC2']).join(GSE70138_Broad_LINCS_sig_info)
#palette = sns.color_palette("muted", n_colors=5)
#palette =sns.color_palette('bright')
sns.set_style("white")
sns.scatterplot(x='PC1',y='PC2',hue='pert_id',data=pca_df, linewidth=0.2, s=30, alpha=1).set_title('PCA')
# Out:
# Principal Component Analysis (PCA)
# Text(0.5, 1.0, 'PCA')

# %%
#Visualize data using Principal Component Analysis (on cell data)
print("Principal Component Analysis (PCA)")
pca = PCA(n_components = 2).fit_transform(X_std)
pca_df = pd.DataFrame(data=pca, columns=['PC1','PC2']).join(GSE92742_Broad_LINCS_cell_info)
#palette = sns.color_palette("muted", n_colors=5)
#palette =sns.color_palette('bright')
sns.set_style("white")
sns.scatterplot(x='PC1',y='PC2',hue='primary_site',data=pca_df, linewidth=0.2, s=30, alpha=1).set_title('PCA')
# Out:
# Principal Component Analysis (PCA)
# Text(0.5, 1.0, 'PCA')

# %%
#Visualize data using t-SNE.( on cell data)
print("t-Distributed Stochastic Neighbor Embedding (tSNE)")
model = TSNE(learning_rate = 10, n_components = 2, random_state=123, perplexity = 30)
tsne = model.fit_transform(X_std)
tsne_df = pd.DataFrame(data=tsne, columns=['t-SNE1','t-SNE2']).join(GSE92742_Broad_LINCS_cell_info)
#palette = sns.color_palette("muted", n_colors=5)
sns.set_style("white")
sns.scatterplot(x='t-SNE1',y='t-SNE2',hue='primary_site',data=tsne_df, linewidth=0.2, s=30, alpha=1).set_title('t-SNE')
# Out:
# t-Distributed Stochastic Neighbor Embedding (tSNE)

# %%
#Visualize data using UMAP. 
print("Uniform Manifold Approximation and Projection (UMAP)")
model = UMAP(n_neighbors = 40, min_dist = 0.4, n_components = 2)
umap = model.fit_transform(X_std)
umap_df = pd.DataFrame(data=umap, columns=['UMAP1','UMAP2']).join(GSE70138_Broad_LINCS_sig_info)
#palette = sns.color_palette("muted", n_colors=5)
sns.set_style("white")
sns.scatterplot(x='UMAP1',y='UMAP2',hue='cell_id',data=umap_df, linewidth=0.2, s=30, alpha=1).set_title('UMAP')
# Out:
# Uniform Manifold Approximation and Projection (UMAP)
# Text(0.5, 1.0, 'UMAP')

# %%
#Visualize data using UMAP.(on cell data)
print("Uniform Manifold Approximation and Projection (UMAP)")
model = UMAP(n_neighbors = 40, min_dist = 0.4, n_components = 2)
umap = model.fit_transform(X_std)
umap_df = pd.DataFrame(data=umap, columns=['UMAP1','UMAP2']).join(GSE92742_Broad_LINCS_cell_info)
#palette = sns.color_palette("muted", n_colors=5)
sns.set_style("white")
sns.scatterplot(x='UMAP1',y='UMAP2',hue='primary_site',data=umap_df, linewidth=0.2, s=30, alpha=1).set_title('UMAP')
# Out:
# Uniform Manifold Approximation and Projection (UMAP)
# Text(0.5, 1.0, 'UMAP')

# %% [markdown]
# Exploration of breast Data

# %%
data_breast = breast_GSK_1059615_data
data_breast.head()
# Out:
#                    cid       780      7849  ...     23038     57048     79716
# 0  LJP005_BT20_24H:E01  0.920150  1.845150  ...  2.741600 -1.355950 -1.010350
# 1  LJP005_BT20_24H:E02  1.484325  2.598958  ...  2.448636  0.297333  1.183148
# 2  LJP005_BT20_24H:E03  0.989671  1.779115  ...  3.301758  0.464175  2.132145
# 3  LJP005_BT20_24H:E04  1.272662  0.290275  ...  3.118534  0.303359 -1.310363
# 4  LJP005_BT20_24H:E05  0.818583 -0.426627  ...  4.634474  0.002101 -1.312246
#
# [5 rows x 979 columns]

# %%
 # Suppression de cid
 del data_breast['cid']

# %%
X = data_breast.values
X[0:5]
# Out:
# array([[ 9.2015004e-01,  1.8451500e+00,  1.1115000e+00, ...,
#          2.7416000e+00, -1.3559500e+00, -1.0103500e+00],
#        [ 1.4843253e+00,  2.5989585e+00, -5.3504730e-01, ...,
#          2.4486360e+00,  2.9733300e-01,  1.1831481e+00],
#        [ 9.8967147e-01,  1.7791153e+00,  6.1553404e-02, ...,
#          3.3017578e+00,  4.6417540e-01,  2.1321447e+00],
#        [ 1.2726624e+00,  2.9027500e-01, -2.7486804e-01, ...,
#          3.1185338e+00,  3.0335870e-01, -1.3103632e+00],
#        [ 8.1858325e-01, -4.2662668e-01,  1.2230301e+00, ...,
#          4.6344740e+00,  2.1007060e-03, -1.3122461e+00]])

# %%
X_std = StandardScaler().fit_transform(X)

# %%
# PCA on the breast_data

#Visualize data using Principal Component Analysis.
print("Principal Component Analysis (PCA)")
pca = PCA(n_components = 2).fit_transform(X_std)
pca_df = pd.DataFrame(data=pca, columns=['PC1','PC2']).join(breast_data)
#palette = sns.color_palette("muted", n_colors=5)
#palette =sns.color_palette('bright')
sns.set_style("white")
sns.scatterplot(x='PC1',y='PC2',hue='pert_id',data=pca_df, linewidth=0.2, s=30, alpha=1).set_title('PCA')
# Out:
# Principal Component Analysis (PCA)
# Text(0.5, 1.0, 'PCA')

# %%
print(breast_data.groupby(['sig_id', 'pert_iname']).count())
# Out:
#                                     pert_id  pert_type  ...  Unnamed: 9  Unnamed: 10
# sig_id                  pert_iname                      ...
# LJP005_BT20_24H:A03     DMSO              1          1  ...           0            0
# LJP005_BT20_24H:A04     DMSO              1          1  ...           0            0
# LJP005_BT20_24H:A05     DMSO              1          1  ...           0            0
# LJP005_BT20_24H:A06     DMSO              1          1  ...           0            0
# LJP005_BT20_24H:A07     CP-724714         1          1  ...           0            0
# ...                                     ...        ...  ...         ...          ...
# XPR002_MCF7.311_96H:P20 LUCIFERASE        1          1  ...           0            0
# XPR002_MCF7.311_96H:P21 CDH1              1          1  ...           0            0
# XPR002_MCF7.311_96H:P22 FASN              1          1  ...           0            0
# ...

# %%
# PCA on the breast_data

#Visualize data using Principal Component Analysis.
print("Principal Component Analysis (PCA)")
pca = PCA(n_components = 2).fit_transform(X_std)
pca_df = pd.DataFrame(data=pca, columns=['PC1','PC2']).join(breast_data)
#palette = sns.color_palette("muted", n_colors=5)
#palette =sns.color_palette('bright')
sns.set_style("white")
sns.scatterplot(x='PC1',y='PC2',hue='pert_iname',data=pca_df, linewidth=0.2, s=30, alpha=1).set_title('PCA')
# Out:
# Principal Component Analysis (PCA)
# Text(0.5, 1.0, 'PCA')

# %%
pca_df
# Out:
#            PC1        PC2  ... Unnamed: 9 Unnamed: 10
# 0    30.243018   5.214396  ...        NaN         NaN
# 1    30.555211   4.098833  ...        NaN         NaN
# 2    23.188757   6.488468  ...        NaN         NaN
# 3     7.447416   6.384331  ...        NaN         NaN
# 4   -14.655398   0.708271  ...        NaN         NaN
# ..         ...        ...  ...        ...         ...
# 139   5.290439  16.155975  ...        NaN         NaN
# 140  16.081135  -0.003086  ...        NaN         NaN
# 141   5.182296  -0.653736  ...        NaN         NaN
# 142  -4.769491   0.786619  ...        NaN         NaN
# 143  -1.000289  16.875264  ...        NaN         NaN
#
# [144 rows x 13 columns]

# %%
# UMAP on breast_data

print("Uniform Manifold Approximation and Projection (UMAP)")
model = UMAP(n_neighbors = 40, min_dist = 0.4, n_components = 2)
umap = model.fit_transform(X_std)
umap_df = pd.DataFrame(data=umap, columns=['UMAP1','UMAP2']).join(breast_data)
#palette = sns.color_palette("muted", n_colors=5)
sns.set_style("white")
sns.scatterplot(x='UMAP1',y='UMAP2',hue='pert_id',data=umap_df, linewidth=0.2, s=30, alpha=1).set_title('UMAP')
print(umpa.head())
# Out:
# Uniform Manifold Approximation and Projection (UMAP)
# Text(0.5, 1.0, 'UMAP')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
regression_model = LinearRegression()
# Fit the data(train the model)
UMAP1= umap_df['UMAP1']
UMAP2= umap_df['UMAP2']
x = UMAP1 
y = UMAP2

regression_model.fit(UMAP1, UMAP2)
#y_predicted = regression_model.predict(UMAP1)

#UMAP_resid <- lm(integrated_data@reductions$umap@cell.embeddings[,2]~integrated_data@reductions$umap@cell.embeddings[,1])

#UMAP_resid_batch <- lm(UMAP_resid$residuals ~ integrated_data$batch)
#summary(UMAP_resid_batch)$r.squared

# %%
from sklearn.linear_model import LinearRegression

umap_df
x= umap_df['UMAP1']
y= umap_df['UMAP2']


print(x,y)

regression_model = LinearRegression()
regression_model.fit(x,y)

# %%
# UMAP on breast_data

print("Uniform Manifold Approximation and Projection (UMAP)")
model = UMAP(n_neighbors = 40, min_dist = 0.4, n_components = 2)
umap = model.fit_transform(X_std)
umap_df = pd.DataFrame(data=umap, columns=['UMAP1','UMAP2']).join(breast_data)
#palette = sns.color_palette("muted", n_colors=5)
sns.set_style("white")
sns.scatterplot(x='UMAP1',y='UMAP2',hue='pert_type',data=umap_df, linewidth=0.2, s=30, alpha=1).set_title('UMAP')
# Out:
# Uniform Manifold Approximation and Projection (UMAP)
# Text(0.5, 1.0, 'UMAP')

# %%
breast_data['pert_id'].unique
# Out:
# <bound method Series.unique of 0                  DMSO
# 1                  DMSO
# 2                  DMSO
# 3                  DMSO
# 4         BRD-K76908866
#               ...
# 20295    BRDN0000733153
# 20296    BRDN0001054936
# 20297    BRDN0001054869
# 20298    BRDN0000734431
# 20299    BRDN0000582717
# Name: pert_id, Length: 20300, dtype: object>

# %% [markdown]
# Exploration Of Data

# %% [markdown]
# Cell data exploration

# %%
print(data.sample_type. describe())
# Out:
# count        99
# unique        4
# top       tumor
# freq         71
# Name: sample_type, dtype: object

# %%
data = GSE92742_Broad_LINCS_cell_info
cell_info_filt = data[data['cell_type']!= '-666']
Cell_type_counts = cell_info_filt['cell_type'].value_counts().reset_index()
Cell_type_counts.columns = ['cell_type', 'count']

fg = sns.barplot(y='cell_type', x='count', data=Cell_type_counts)
_ = fg.set(xlabel='Number of Cell-type', ylabel='Type', title='Cell-type representation'.format(cell_info_filt.shape[0]))
plt.show()

# %%
cell_info_filt = data[data['cell_type']!= '-666']
Cell_type_counts = cell_info_filt['cell_type'].value_counts().reset_index()
Cell_type_counts.columns = ['cell_type', 'count']

fg = sns.barplot(y='cell_type', x='count', data=Cell_type_counts)
_ = fg.set(xlabel='Number of Cell-type', ylabel='Type', title='Cell-type representation'.format(cell_info_filt.shape[0]))
plt.show()

# %%
cell_info_filt = data[data['sample_type']!= '-666']
Cell_type_counts = cell_info_filt['sample_type'].value_counts().reset_index()
Cell_type_counts.columns = ['sample_type', 'count']

fg = sns.barplot(y='sample_type', x='count', data=Cell_type_counts)
_ = fg.set(xlabel='Number of sample-type', ylabel='Type', title='sample-type representation'.format(cell_info_filt.shape[0]))
plt.show()

# %%
cell_info_filt = data[data['primary_site']!= '-666']
Cell_type_counts = cell_info_filt['primary_site'].value_counts().reset_index()
Cell_type_counts.columns = ['primary_site', 'count']

fg = sns.barplot(y='primary_site', x='count', data=Cell_type_counts)
_ = fg.set(xlabel='Number of primary_site', ylabel='Type', title='primary_site representation'.format(cell_info_filt.shape[0]))
plt.show()

# %% [markdown]
# Breast_data exploration

# %%
breast_data.head()
# Out:
#                 sig_id        pert_id  ... Unnamed: 9 Unnamed: 10
# 0  LJP005_BT20_24H:A03           DMSO  ...        NaN         NaN
# 1  LJP005_BT20_24H:A04           DMSO  ...        NaN         NaN
# 2  LJP005_BT20_24H:A05           DMSO  ...        NaN         NaN
# 3  LJP005_BT20_24H:A06           DMSO  ...        NaN         NaN
# 4  LJP005_BT20_24H:A07  BRD-K76908866  ...        NaN         NaN
#
# [5 rows x 11 columns]

# %%
print(breast_data.pert_iname.describe())
# Out:
# count     20300
# unique     1818
# top        DMSO
# freq       1155
# Name: pert_iname, dtype: object

# %%
print(breast_data.pert_type.describe())
# Out:
# count      20300
# unique        10
# top       trt_cp
# freq       18359
# Name: pert_type, dtype: object

# %%
cell_info_filt = breast_data[breast_data['pert_iname']!= '-666']
Cell_type_counts = cell_info_filt['pert_iname'].value_counts().reset_index()
Cell_type_counts.columns = ['pert_iname', 'count']

fg = sns.barplot(y='pert_iname', x='count', data=Cell_type_counts)
_ = fg.set(xlabel='Number of pert_iname', ylabel='Type', title='pert_iname representation'.format(cell_info_filt.shape[0]))
plt.show()

# %%
cell_info_filt = breast_data[breast_data['pert_type']!= '-666']
Cell_type_counts = cell_info_filt['pert_type'].value_counts().reset_index()
Cell_type_counts.columns = ['pert_type', 'count']

fg = sns.barplot(y='pert_type', x='count', data=Cell_type_counts)
_ = fg.set(xlabel='Number of pert_type', ylabel='Type', title='pert_type representation'.format(cell_info_filt.shape[0]))
plt.show()

# %%
cell_info_filt = breast_data[breast_data['pert_id']!= '-666']
Cell_type_counts = cell_info_filt['pert_id'].value_counts().reset_index()
Cell_type_counts.columns = ['pert_iname', 'count']

fg = sns.barplot(y='pert_id', x='count', data=Cell_type_counts)
_ = fg.set(xlabel='Number of pert_id', ylabel='Type', title='pert_iname representation'.format(cell_info_filt.shape[0]))
plt.show()

# %%
print(breast_data.pert_type.describe())
# Out:
# count      20300
# unique        10
# top       trt_cp
# freq       18359
# Name: pert_type, dtype: object

# %%
breast_data['pert_iname'].unique
# Out:
# <bound method Series.unique of 0             DMSO
# 1             DMSO
# 2             DMSO
# 3             DMSO
# 4        CP-724714
#            ...
# 20295          JUN
# 20296          KIT
# 20297         CRKL
# 20298         MTTP
# 20299        HDAC3
# Name: pert_iname, Length: 20300, dtype: object>

# %%
#len(breast_data['pert_iname']== 'GSK_1059615')
# Out:
# 20300

# %%
print(breast_GSK_1059615_data.describe())
# Out:
#               780        7849        6193  ...       23038       57048       79716
# count  144.000000  144.000000  144.000000  ...  144.000000  144.000000  144.000000
# mean     0.572828    0.383647    0.112308  ...    0.802931    0.199367    0.378132
# std      1.101207    1.064494    0.738941  ...    1.352902    1.197343    1.199414
# min     -2.214390   -2.165228   -1.120185  ...   -1.597880   -3.843949   -5.347150
# 25%     -0.147565   -0.221425   -0.390040  ...   -0.132634   -0.311495   -0.304734
# 50%      0.447520    0.207627    0.010318  ...    0.453778    0.128701    0.358834
# 75%      1.153102    0.850165    0.419532  ...    1.491864    0.611733    1.208951
# max      4.340421    4.470048    3.672400  ...    5.984400    4.194780    3.913150
#
# [8 rows x 978 columns]

# %%
breast_GSK_1059615_data['780'].count
#breast_GSK_1059615_data.head()
# Out:
# <bound method Series.count of 0       0.484921
# 1       1.199629
# 2       0.284552
# 3      -0.093108
# 4       0.155570
#           ...
# 1294   -0.318100
# 1295   -1.306500
# 1296   -0.323700
# 1297    0.079100
# 1298   -2.289100
# Name: 780, Length: 1299, dtype: float64>

# %% [markdown]
# DMSO Exploration

# %%
MG_132_DMSO.head()
# Out:
#   class cell type                  cid  ...     23038     57048     79716
# 0  DMSO      A375  LJP005_A375_24H:A03  ... -1.076814 -0.240803  0.105998
# 1  DMSO      A375  LJP005_A375_24H:A04  ... -0.904253  0.040530 -0.619656
# 2  DMSO      A375  LJP005_A375_24H:A05  ... -0.939757 -0.093534 -0.260954
# 3  DMSO      A375  LJP005_A375_24H:A06  ... -0.468805  1.793977 -0.642835
# 4  DMSO      A375  LJP005_A375_24H:B03  ... -0.134766 -0.090636 -0.133798
#
# [5 rows x 981 columns]

# %%
features = ['cell type', 'cid']
#x = MG_132_DMSO.loc[:, -(features)].values
#x = MG_132_DMSO.drop(features , inplace=True)
#x= del MG_132_DMSO['cell type', 'cid']
x = MG_132_DMSO.drop (['cell type','class','cid'],axis=1)

# %%
temp.head()
# Out:
#                    cid       780      7849  ...     23038     57048     79716
# 0  LJP005_A375_24H:A03 -0.154526 -1.165480  ... -1.076814 -0.240803  0.105998
# 1  LJP005_A375_24H:A04  0.113874 -0.883416  ... -0.904253  0.040530 -0.619656
# 2  LJP005_A375_24H:A05 -0.038252 -0.183913  ... -0.939757 -0.093534 -0.260954
# 3  LJP005_A375_24H:A06  0.466993 -0.584319  ... -0.468805  1.793977 -0.642835
# 4  LJP005_A375_24H:B03 -0.026035 -0.101141  ... -0.134766 -0.090636 -0.133798
#
# [5 rows x 979 columns]

# %%
y = MG_132_DMSO.loc[:,['class']].values

# %%
x = StandardScaler().fit_transform(x)

# %%
X_std = StandardScaler().fit_transform(x)

# %%
# PCA on the DMSO-data

#Visualize data using Principal Component Analysis.
print("Principal Component Analysis (PCA)")
pca = PCA(n_components = 2).fit_transform(X_std)
pca_df = pd.DataFrame(data=pca, columns=['PC1','PC2']).join(MG_132_DMSO)
#palette = sns.color_palette("muted", n_colors=5)
#palette =sns.color_palette('bright')
sns.set_style("white")
sns.scatterplot(x='PC1',y='PC2',hue='cell type',data=pca_df, linewidth=0.2, s=30, alpha=1).set_title('PCA')
# Out:
# Principal Component Analysis (PCA)
# Text(0.5, 1.0, 'PCA')

# %%
# PCA on the DMSO-data

#Visualize data using Principal Component Analysis.
print("Principal Component Analysis (PCA)")
pca = PCA(n_components = 2).fit_transform(X_std)
pca_df = pd.DataFrame(data=pca, columns=['PC1','PC2']).join(MG_132_DMSO)
#palette = sns.color_palette("muted", n_colors=5)
#palette =sns.color_palette('bright')
sns.set_style("white")
sns.scatterplot(x='PC1',y='PC2',hue='class',data=pca_df, linewidth=0.2, s=30, alpha=1).set_title('PCA')
# Out:
# Principal Component Analysis (PCA)
# Text(0.5, 1.0, 'PCA')

# %%
# UMAP on MG_132_DMSO

print("Uniform Manifold Approximation and Projection (UMAP)")
model = UMAP(n_neighbors = 40, min_dist = 0.4, n_components = 2)
umap = model.fit_transform(X_std)
umap_df = pd.DataFrame(data=umap, columns=['UMAP1','UMAP2']).join(MG_132_DMSO)
#palette = sns.color_palette("muted", n_colors=5)
sns.set_style("white")
sns.scatterplot(x='UMAP1',y='UMAP2',hue='cell type',data=umap_df, linewidth=0.2, s=30, alpha=1).set_title('UMAP')
# Out:
# Uniform Manifold Approximation and Projection (UMAP)
# Text(0.5, 1.0, 'UMAP')

# %%
# UMAP on MG_132_DMSO

print("Uniform Manifold Approximation and Projection (UMAP)")
model = UMAP(n_neighbors = 40, min_dist = 0.4, n_components = 2)
umap = model.fit_transform(X_std)
umap_df = pd.DataFrame(data=umap, columns=['UMAP1','UMAP2']).join(MG_132_DMSO)
#palette = sns.color_palette("muted", n_colors=5)
sns.set_style("white")
sns.scatterplot(x='UMAP1',y='UMAP2',hue='class',data=umap_df, linewidth=0.2, s=30, alpha=1).set_title('UMAP')
# Out:
# Uniform Manifold Approximation and Projection (UMAP)
# Text(0.5, 1.0, 'UMAP')
